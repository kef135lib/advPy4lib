# %% [markdown]
# <a href="https://colab.research.google.com/github/kef135lib/advPy4lib/blob/main/KFloyd_Week_1_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 Homework
#
# (Be sure to save this to Drive before starting)
#
# For this week we are going to practice requesting information from an API and manipulating it as JSON and as a Dataframe.
#
# We are going to keep working with Collection Builder. Head over to the [Collection Builder Example Projects](https://collectionbuilder.github.io/cb-examples/browse.html) listing and find a site that interests you. Spend some time browsing the website to get acquainted with its contents before proceeding with the questions.

# %%
#The Libraries we will need
import requests
import json
import pandas as pd
from random import randrange

# %%
# @markdown **H1** Find the URL of for the  _metadata.json_ of your selected site and paste it in here.
json_cb_url = "https://cpplibrary.github.io/postcards-compound/data/metadata.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_url)
#all of the data from the sites
total_cb_data = response_cb.json()
#just the 'objects' indexed in the site
objects_cb_data = total_cb_data['objects']
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# **H2** Run the 'show random cell' a few times to get a sense of what kind of data is in your chosen site.

# %%
#Run this a few times to see random entries in the JSON data that you retrieved.
random_entry = randrange(len(objects_cb_data))
print(json.dumps(objects_cb_data[random_entry],indent=2))
# Out:
# {
#   "objectid": "coll008",
#   "filename": "cpp_c0015_b0001_i007a.jpg",
#   "compound": "cpp_c0015_b0001_i007b.jpg",
#   "title": "Antez",
#   "description": "[1921-1944 \"Antez\", a beautiful chestnut stallion with flaxen mane and tail, is one of a stable of more than 40 full blooded Arabian horses owned by the W.K. Kellogg Arabian Horse Ranch, of Pomona, California. The owner of this ranch is the well known cereal manufacturer of Battle Creek, Michigan. \"Antez\" was the Champion Arabian Stallion at the Los Angeles County Fair in 1928.]",
#   "postcard_type": "Image;StillImage",
#   "subject": "Arabian horse; California State Polytechnic University, Pomona; horse; postcards; W.K. Kellogg Arabian Horse Center",
#   "location": "Pomona ",
#   "state": "California",
#   "publisher": "California State Polytechnic University, Pomona",
#   "publisher_location": "Pomona, CA",
#   "source": "W.K. Kellogg Arabian Horse Library Postcard and Notecard Collection",
#   "identifier": "cpp_c0015_b0001_i007a",
#   "rights": "Public domain",
#   "standardized_rights": "http://rightsstatements.org/vocab/NoC-US/1.0/",
#   "type": "Image;StillImage",
#   "format": "image/jpeg",
#   "language": "en",
#   "latitude": "34.0589",
#   "longitude": "-117.8194",
#   "cdmid": "cpp_c0015_b0001_i007a",
#   "reference_url": "https://cpplibrary.github.io/postcards-compound/item.html?id=coll008"
# }

# %% [markdown]
# ## Different Fields!
#
# You can create any number of datafields and correpsonding values for those fields with a Collection Builder site. So the results from the output from the cell above will probably have wildly different results from [my site](https://elibtronic.github.io/AIL_Database/data.html) that we worked on in the Workalong notebook.
#
#
# You can see all of these options from grabbing the _facets.json_ URL from a collection builder homepage. Find that URL for your selected site for **H3**

# %%
# @markdown **H3** Find the URL of the facets.json for your selected site and paste it in here.
json_cb_facets_url = "https://cpplibrary.github.io/postcards-compound/data/facets.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_facets_url)
#all of the data from the sites
total_facet_data = response_cb.json()
#just the 'objects' indexed in the site
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# Run the cell below to see what the facets used for this site:

# %%
print(json.dumps(total_facet_data,indent=2))
# Out:
# {
#   "facets": [
#     {
#       "field": "postcard_type",
#       "terms": {
#         "image": 128,
#         "stillimage": 128
#       }
#     },
#     {
#       "field": "photographer",
#       "terms": {}
#     },
#     {
#       "field": "subject",
#       "terms": {
#         "arabian horse": 103,
#         "arabian horses": 1,
#         "architecture": 6,
#         "boats": 1,
#         "california state polytechnic university, pomona": 79,
#         "campuses": 2,
#         "cereal products industry": 5,
#         "factories": 3,
#         "highways": 1,
#         "horse": 104,
#         "horse show": 1,
#         "horse shows": 4,
#         "horsemanship": 37,
#         "horses": 1,
#         "industrial recreation": 2,
#         "kellogg company": 5,
#         "kellogg house, pomona": 3,
#         "kellogg, will keith, 1860-1951": 1,
#         "macatawa, lake (mich.)": 1,
#         "postcards": 128,
#         "show horses": 2,
#         "stables": 7,
#         "university campuses": 3,
#         "w.k. kellogg arabian horse center": 96
#       }
#     },
#     {
#       "field": "location",
#       "terms": {
#         "pomona": 128
#       }
#     },
#     {
#       "field": "state",
#       "terms": {
#         "california": 128
#       }
#     },
#     {
#       "field": "publisher",
#       "terms": {
#         "california state polytechnic university, pomona": 128
#       }
#     },
#     {
#       "field": "publisher_location",
#       "terms": {
#         "pomona, ca": 128
#       }
#     },
#     {
#       "field": "original_format",
#       "terms": {}
#     },
#     {
#       "field": "format",
#       "terms": {
#         "image/jpeg": 128
#       }
#     }
#   ]
# }

# %% [markdown]
# **H3** Try to read the JSON that is displayed to the screen. What possible facets are there in the the data. Fill them in the markdown list in the cell below. Add as many entries as you need to describe the site

# %% [markdown]
# Facets in my site are:
# - postcard_type
# - photographer
# - subject
# - location
# - state
# - publisher
# - publisher_location
# - original_format
# - format

# %% [markdown]
# **H4** Which facet shows up the most for your selected site? Put your answer in the cell below

# %% [markdown]
# This facet value that shows up the most is "arabian horse." It is used 103 times on my selected site.

# %% [markdown]
# **H5** Turn the site _metadata.json_ data into a dataframe by completing the cell below. Part of it is written for you. You just need to modify line 4.

# %%
#H5

cb_data = pd.read_json(json_cb_url)
cb_normalized = pd.json_normalize(cb_data['objects'])
cb_normalized
# Out:
#     objectid                   filename                   compound  \
# 0    coll002  cpp_c0015_b0001_i001a.jpg  cpp_c0015_b0001_i001b.jpg
# 1    coll003  cpp_c0015_b0001_i002a.jpg  cpp_c0015_b0001_i002b.jpg
# 2    coll004  cpp_c0015_b0001_i003a.jpg  cpp_c0015_b0001_i003b.jpg
# 3    coll005  cpp_c0015_b0001_i004a.jpg  cpp_c0015_b0001_i004b.jpg
# 4    coll006  cpp_c0015_b0001_i005a.jpg  cpp_c0015_b0001_i005b.jpg
# ..       ...                        ...                        ...
# 123  coll125  cpp_c0015_b0001_i124a.jpg  cpp_c0015_b0001_i124b.jpg
# 124  coll126  cpp_c0015_b0001_i125a.jpg  cpp_c0015_b0001_i125b.jpg
# 125  coll127  cpp_c0015_b0001_i126a.jpg  cpp_c0015_b0001_i126b.jpg
# 126  coll128  cpp_c0015_b0001_i127a.jpg  cpp_c0015_b0001_i127b.jpg
# 127  coll129  cpp_c0015_b0001_i128a.jpg  cpp_c0015_b0001_i128b.jpg
#
#                                                  title  \
# 0                                            Abu Farwa
# 1                                                 Alyf
# 2                                                 Alyf
# 3                                                 Alyf
# 4                                                 Alyf
# ..                                                 ...
# 123  Stables on W.K. Kellogg Arabian Horse Ranch, P...
# 124  Stables on W.K. Kellogg Arabian Horse Ranch, P...
# 125                                        Union Plaza
# 126  Visitors Being Entertained at Stables on W.K. ...
# 127       W.K. Kellogg's Institute of Animal Husbandry
#
#                                            description     postcard_type  \
# 0    Verso [1940-1972 Abu Farwa's name is practical...  Image;StillImage
# 1    Verso: ["Alyf" foaled in 1938, was the winner ...  Image;StillImage
# 2    Recto: [Arabian Stallion, Alyf, Pomona Quarter...  Image;StillImage
# 3    Verso: [Alyf, foaled 1938. Head study of eight...  Image;StillImage
# 4    Verso: [Alyf, foaled 1938. Head study of eight...  Image;StillImage
# ..                                                 ...               ...
# 123  Verso: [The W.K. Kellogg Arabian Horse Ranch, ...  Image;StillImage
# 124  Verso: [The W.K. Kellogg Arabian Horse Ranch, ...  Image;StillImage
# 125  Verso: [Union Plaza, the original stables on t...  Image;StillImage
# 126  Verso: [The W.K. Kellogg Arabian Horse Ranch, ...  Image;StillImage
# 127  Recto: [W.K. Kellogg's Institute of Animal Hus...  Image;StillImage
#
#                                                subject location       state  \
# 0                                    horses; postcards  Pomona   California
# 1    Arabian horse; California State Polytechnic Un...  Pomona   California
# 2    Arabian horse; California State Polytechnic Un...  Pomona   California
# 3    Arabian horse; California State Polytechnic Un...  Pomona   California
# 4    Arabian horse; California State Polytechnic Un...  Pomona   California
# ..                                                 ...      ...         ...
# 123  California State Polytechnic University, Pomon...  Pomona   California
# 124  California State Polytechnic University, Pomon...  Pomona   California
# 125  Architecture; California State Polytechnic Uni...  Pomona   California
# 126  Arabian horses; horse; horse show; postcards; ...  Pomona   California
# 127  Architecture; campuses; postcards; W.K. Kellog...  Pomona   California
#
#                                            publisher  ...  \
# 0    California State Polytechnic University, Pomona  ...
# 1    California State Polytechnic University, Pomona  ...
# 2    California State Polytechnic University, Pomona  ...
# 3    California State Polytechnic University, Pomona  ...
# 4    California State Polytechnic University, Pomona  ...
# ..                                               ...  ...
# 123  California State Polytechnic University, Pomona  ...
# 124  California State Polytechnic University, Pomona  ...
# 125  California State Polytechnic University, Pomona  ...
# 126  California State Polytechnic University, Pomona  ...
# 127  California State Polytechnic University, Pomona  ...
#
#                 identifier         rights  \
# 0    cpp_c0015_b0001_i001a  Public domain
# 1    cpp_c0015_b0001_i002a  Public domain
# 2    cpp_c0015_b0001_i003a  Public domain
# 3    cpp_c0015_b0001_i004a  Public domain
# 4    cpp_c0015_b0001_i005a  Public domain
# ..                     ...            ...
# 123  cpp_c0015_b0001_i124a  Public domain
# 124  cpp_c0015_b0001_i125a  Public domain
# 125  cpp_c0015_b0001_i126a  Public domain
# 126  cpp_c0015_b0001_i127a  Public domain
# 127  cpp_c0015_b0001_i128a  Public domain
#
#                                standardized_rights              type  \
# 0    http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# 1    http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# 2    http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# 3    http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# 4    http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# ..                                             ...               ...
# 123  http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# 124  http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# 125  http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# 126  http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# 127  http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
#
#          format language latitude  longitude                  cdmid  \
# 0    image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i001a
# 1    image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i002a
# 2    image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i003a
# 3    image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i004a
# 4    image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i005a
# ..          ...      ...      ...        ...                    ...
# 123  image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i124a
# 124  image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i125a
# 125  image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i126a
# 126  image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i127a
# 127  image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i128a
#
#                                          reference_url
# 0    https://cpplibrary.github.io/postcards-compoun...
# 1    https://cpplibrary.github.io/postcards-compoun...
# 2    https://cpplibrary.github.io/postcards-compoun...
# 3    https://cpplibrary.github.io/postcards-compoun...
# 4    https://cpplibrary.github.io/postcards-compoun...
# ..                                                 ...
# 123  https://cpplibrary.github.io/postcards-compoun...
# 124  https://cpplibrary.github.io/postcards-compoun...
# 125  https://cpplibrary.github.io/postcards-compoun...
# 126  https://cpplibrary.github.io/postcards-compoun...
# 127  https://cpplibrary.github.io/postcards-compoun...
#
# [128 rows x 22 columns]

# %%
#Run this a few times to see random entries in your dataframe
cb_normalized.sample(10)
# Out:
#     objectid                   filename                   compound  \
# 107  coll109  cpp_c0015_b0001_i108a.jpg  cpp_c0015_b0001_i108b.jpg
# 93   coll095  cpp_c0015_b0001_i094a.jpg  cpp_c0015_b0001_i094b.jpg
# 8    coll010  cpp_c0015_b0001_i009a.jpg  cpp_c0015_b0001_i009b.jpg
# 59   coll061  cpp_c0015_b0001_i060a.jpg  cpp_c0015_b0001_i060b.jpg
# 85   coll087  cpp_c0015_b0001_i086a.jpg  cpp_c0015_b0001_i086b.jpg
# 119  coll121  cpp_c0015_b0001_i120a.jpg  cpp_c0015_b0001_i120b.jpg
# 114  coll116  cpp_c0015_b0001_i115a.jpg  cpp_c0015_b0001_i115b.jpg
# 83   coll085  cpp_c0015_b0001_i084a.jpg  cpp_c0015_b0001_i084b.jpg
# 7    coll009  cpp_c0015_b0001_i008a.jpg  cpp_c0015_b0001_i008b.jpg
# 95   coll097  cpp_c0015_b0001_i096a.jpg  cpp_c0015_b0001_i096b.jpg
#
#                                                  title  \
# 107              Macatawa Yacht Harbor, Holland, Mich.
# 93                                    The Three Graces
# 8                                                Antez
# 59                                              Maazal
# 85                           Six-Horse Percheron Hitch
# 119  Stables on W.K. Kellogg Arabian Horse Ranch, P...
# 114                                    Cal Poly Pomona
# 83                                               Sikin
# 7                                                Antez
# 95                                    The Three Graces
#
#                                            description     postcard_type  \
# 107     Recto: [Macatawa Yacht Harbor, Holland, Mich.]  Image;StillImage
# 93   Recto: [The Three Graces, Arabian mares and co...  Image;StillImage
# 8    [1921-1944 "Antez", a beautiful chestnut stall...  Image;StillImage
# 59   Maazal, foaled April 25, 1953. Verso: [Three Y...  Image;StillImage
# 85   Verso: [California State Polytechnic College, ...  Image;StillImage
# 119  Verso: [The W.K. Kellogg Arabian Horse Ranch, ...  Image;StillImage
# 114                           Recto: [Cal Poly Pomona]  Image;StillImage
# 83   Recto: [Sikin, foaled 1933. W.K. Kellogg's Ins...  Image;StillImage
# 7    [1921-1944 "Antez", a beautiful chestnut stall...  Image;StillImage
# 95   Recto: [The Three Graces, Arabian mares and co...  Image;StillImage
#
#                                                subject location       state  \
# 107           Boats; Macatawa, Lake (Mich.); postcards  Pomona   California
# 93   Arabian horse; California State Polytechnic Un...  Pomona   California
# 8    Arabian horse; California State Polytechnic Un...  Pomona   California
# 59                     Arabian horse; horse; postcards  Pomona   California
# 85   Arabian horse; California State Polytechnic Un...  Pomona   California
# 119  California State Polytechnic University, Pomon...  Pomona   California
# 114  Architecture; California State Polytechnic Uni...  Pomona   California
# 83   Arabian horse; horse; postcards; W.K. Kellogg ...  Pomona   California
# 7    Arabian horse; California State Polytechnic Un...  Pomona   California
# 95   Arabian horse; California State Polytechnic Un...  Pomona   California
#
#                                            publisher  ...  \
# 107  California State Polytechnic University, Pomona  ...
# 93   California State Polytechnic University, Pomona  ...
# 8    California State Polytechnic University, Pomona  ...
# 59   California State Polytechnic University, Pomona  ...
# 85   California State Polytechnic University, Pomona  ...
# 119  California State Polytechnic University, Pomona  ...
# 114  California State Polytechnic University, Pomona  ...
# 83   California State Polytechnic University, Pomona  ...
# 7    California State Polytechnic University, Pomona  ...
# 95   California State Polytechnic University, Pomona  ...
#
#                 identifier         rights  \
# 107  cpp_c0015_b0001_i108a  Public domain
# 93   cpp_c0015_b0001_i094a  Public domain
# 8    cpp_c0015_b0001_i009a  Public domain
# 59   cpp_c0015_b0001_i060a  Public domain
# 85   cpp_c0015_b0001_i086a  Public domain
# 119  cpp_c0015_b0001_i120a  Public domain
# 114  cpp_c0015_b0001_i115a  Public domain
# 83   cpp_c0015_b0001_i084a  Public domain
# 7    cpp_c0015_b0001_i008a  Public domain
# 95   cpp_c0015_b0001_i096a  Public domain
#
#                                standardized_rights              type  \
# 107  http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# 93   http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# 8    http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# 59   http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# 85   http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# 119  http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# 114  http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# 83   http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# 7    http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
# 95   http://rightsstatements.org/vocab/NoC-US/1.0/  Image;StillImage
#
#          format language latitude  longitude                  cdmid  \
# 107  image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i108a
# 93   image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i094a
# 8    image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i009a
# 59   image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i060a
# 85   image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i086a
# 119  image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i120a
# 114  image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i115a
# 83   image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i084a
# 7    image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i008a
# 95   image/jpeg       en  34.0589  -117.8194  cpp_c0015_b0001_i096a
#
#                                          reference_url
# 107  https://cpplibrary.github.io/postcards-compoun...
# 93   https://cpplibrary.github.io/postcards-compoun...
# 8    https://cpplibrary.github.io/postcards-compoun...
# 59   https://cpplibrary.github.io/postcards-compoun...
# 85   https://cpplibrary.github.io/postcards-compoun...
# 119  https://cpplibrary.github.io/postcards-compoun...
# 114  https://cpplibrary.github.io/postcards-compoun...
# 83   https://cpplibrary.github.io/postcards-compoun...
# 7    https://cpplibrary.github.io/postcards-compoun...
# 95   https://cpplibrary.github.io/postcards-compoun...
#
# [10 rows x 22 columns]

# %% [markdown]
# **H6** This is for bonus!
# Try to write a pandas statement that will display your answer from **H4**. There are plenty of ways to do this, so feel free to use your imagination. What I have started for you here might not work, so feel free to change it as needed.

# %%
number = cb_normalized["subject"].str.contains("Arabian horse;").sum()
print("This facet value that shows up the most is \"arabian horse.\" It is used ",number, " times on my selected site.")
# Out:
# This facet value that shows up the most is "arabian horse." It is used  103  times on my selected site.

# %% [markdown]
# ## All Done!
#
# Congrats you are finished with this week's work. First save as PDF so that you can upload to the Course site then click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work.
